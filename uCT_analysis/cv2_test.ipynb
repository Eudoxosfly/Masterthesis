# %%
from skimage import io
import cv2 as cv
import matplotlib.pyplot as plt
import pyclesperanto as cle

# %%
img = io.imread("test.tif")
plt.figure(figsize=(30,5))
plt.imshow(img, cmap='gray')
plt.figure()
plt.hist(img.ravel(), bins=256, fc='k', ec='k')
# Out:
# (array([2.0000e+00, 0.0000e+00, 1.0000e+00, 2.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 3.0000e+00, 2.0000e+00, 1.0000e+00,
#         0.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#         2.0000e+00, 5.0000e+00, 4.0000e+00, 8.0000e+00, 1.0000e+01,
#         8.0000e+00, 7.0000e+00, 5.0000e+00, 1.3000e+01, 1.1000e+01,
#         1.9000e+01, 1.2000e+01, 1.8000e+01, 1.8000e+01, 2.9000e+01,
#         1.5000e+01, 1.9000e+01, 3.4000e+01, 3.4000e+01, 4.0000e+01,
#         4.3000e+01, 5.2000e+01, 5.0000e+01, 4.1000e+01, 6.8000e+01,
#         5.4000e+01, 5.8000e+01, 6.0000e+01, 7.5000e+01, 7.0000e+01,
#         9.3000e+01, 9.1000e+01, 1.0600e+02, 1.3400e+02, 1.1400e+02,
#         1.0600e+02, 1.2200e+02, 1.4400e+02, 1.5600e+02, 1.6000e+02,
#         1.6100e+02, 1.8400e+02, 2.0500e+02, 2.0000e+02, 2.0700e+02,
#         2.6100e+02, 2.4700e+02, 2.4800e+02, 2.6700e+02, 3.0100e+02,
#         3.3100e+02, 3.6200e+02, 4.0500e+02, 4.0500e+02, 4.2400e+02,
# ...

# %%
clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)
plt.figure(figsize=(30,5))
plt.imshow(cl1, cmap='gray')
plt.figure()
plt.hist(cl1.ravel(), bins=256, fc='k', ec='k')
# Out:
# (array([3.000e+00, 1.100e+01, 1.600e+01, 1.600e+01, 2.900e+01, 4.000e+01,
#         5.300e+01, 6.200e+01, 7.100e+01, 6.900e+01, 1.040e+02, 1.130e+02,
#         1.090e+02, 1.230e+02, 1.230e+02, 1.380e+02, 1.370e+02, 1.370e+02,
#         1.500e+02, 1.810e+02, 1.530e+02, 1.610e+02, 1.700e+02, 1.840e+02,
#         1.900e+02, 1.780e+02, 1.830e+02, 2.070e+02, 2.160e+02, 2.120e+02,
#         2.320e+02, 2.270e+02, 2.360e+02, 2.370e+02, 2.580e+02, 3.070e+02,
#         3.210e+02, 3.120e+02, 3.890e+02, 5.170e+02, 6.660e+02, 8.250e+02,
#         9.390e+02, 1.084e+03, 1.132e+03, 1.203e+03, 1.337e+03, 1.457e+03,
#         1.457e+03, 1.578e+03, 1.657e+03, 1.781e+03, 1.842e+03, 1.961e+03,
#         2.062e+03, 2.187e+03, 2.339e+03, 2.537e+03, 2.620e+03, 2.813e+03,
#         3.034e+03, 3.097e+03, 3.324e+03, 3.444e+03, 3.643e+03, 3.969e+03,
#         4.000e+03, 4.029e+03, 4.273e+03, 4.592e+03, 4.612e+03, 4.905e+03,
#         5.091e+03, 5.319e+03, 5.531e+03, 5.732e+03, 5.826e+03, 6.065e+03,
# ...

# %%
blurred = cle.gaussian_blur(cl1, sigma_x=2.2, sigma_y=2.2)

plt.figure(figsize=(30,5))
plt.imshow(blurred, cmap='gray')
plt.figure()
plt.hist(cle.pull(blurred).ravel(), bins=256, fc='k', ec='k')
plt.show()

# %%
cle.np.ma.masked_array()
